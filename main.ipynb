# %%
import matplotlib.pyplot as plt
import numpy as np
import qiskit as qs


from numpy.random import seed
seed(1)
from datetime import datetime
from scipy.optimize import minimize
from logger import Logger
from qiskit.tools.apps.optimization import SPSA_optimization, SPSA_calibration

SHOTS = 1024 

Q_program = qs.QuantumProgram()


def build_discriminator_gates(phi, circuit, q_register, c_register):
    # phase - cnot - phase - cnot - measurement
    circuit.rx(phi[0], q_register[0])
    circuit.rx(phi[1], q_register[1])
    circuit.cx(q_register[0], q_register[1])
    circuit.rz(phi[2], q_register[0])
    circuit.rz(phi[3], q_register[1])
    circuit.cx(q_register[0], q_register[1])
    circuit.measure(q_register[0], c_register[0])


def build_generator_gates(theta, circuit, q_register):
    circuit.x(q_register[0])
    circuit.u1(theta[0], q_register[0])


def build_discriminator_generator(theta, phi):
    d_g_quantum_register = Q_program.create_quantum_register('d_g_qr', 2)
    d_g_classical_register = Q_program.create_classical_register('d_g_cr', 1)
    d_g_circuit = Q_program.create_circuit('d_g_circuit', [d_g_quantum_register], [d_g_classical_register])

    build_generator_gates(theta, d_g_circuit, d_g_quantum_register)
    build_discriminator_gates(phi, d_g_circuit, d_g_quantum_register, d_g_classical_register)


def build_discriminator(phi):
    d_quantum_register = Q_program.create_quantum_register('d_qr', 2)
    d_classical_register = Q_program.create_classical_register('d_cr', 1)
    d_circuit = Q_program.create_circuit('d_circuit', [d_quantum_register], [d_classical_register])

    # prepare target state
    d_circuit.x(d_quantum_register[0])
    d_circuit.z(d_quantum_register[0])

    build_discriminator_gates(phi, d_circuit, d_quantum_register, d_classical_register)


def discriminator_probability(theta, phi, circuit_name, shots):
    if circuit_name == 'd_circuit':
        build_discriminator(phi)
    else:
        build_discriminator_generator(theta, phi)
    stats_generator = Q_program.execute([circuit_name], backend='local_qasm_simulator', shots=shots)
    stats = stats_generator.get_counts(circuit_name)
    return stats['1'] / shots if '1' in stats else 0.0

# def value_function(theta, phi):
#     d_prob = discriminator_probability(theta, phi, circuit_name='d_circuit', shots=shots)
#     d_g_prob = discriminator_probability(theta, phi, circuit_name='d_g_circuit', shots=shots)
#     # vf = np.log(d_prob) + np.log(1 - d_g_prob)
#     vf = d_prob - d_g_prob
#     return vf


def loss_discriminator(phi, theta):
    d_prob = discriminator_probability(theta, phi, circuit_name='d_circuit', shots=SHOTS)
    d_g_prob = discriminator_probability(theta, phi, circuit_name='d_g_circuit', shots=SHOTS)
    vf = 2*d_prob - d_g_prob
    return - vf


def loss_generator(theta, phi):
    d_g_prob = discriminator_probability(theta, phi, circuit_name='d_g_circuit', shots=SHOTS)
    return - d_g_prob


# options = {'maxiter': 5}
options = None

theta_max = 2 * np.pi
phi_max = 2 * np.pi

theta = np.array([np.random.uniform(0, theta_max)])
theta_bounds = [(0.0, theta_max)]

phi = np.array([np.random.uniform(0.0, phi_max) for _ in range(4)])
phi_bounds = [(0.0, phi_max) for _ in range(4)]

# method = 'L-BFGS-B'
# method = 'TNC'
method ='SLSQP'

max_iter = 10000


# make a plot of the loss landscape

# x = [i * 2 * np.pi / 100 for i in range(100)]
# y = [loss_generator([theta], phi) for theta in x]
# plt.scatter(x, y)
# plt.savefig('generator_loss.pdf')

now = datetime.now().replace(microsecond=0).isoformat()


logger = Logger('logs/{}'.format(now))

# scipy

# for t in range(max_iter):
#     logger.log_scalar('theta', theta[0], t)
#
#     res_phi = minimize(loss_discriminator, args=(theta), x0=phi, method=method, options=options, bounds=phi_bounds)
#     phi = res_phi['x']
#     res_theta = minimize(loss_generator, args=(phi), x0=theta, method=method, options=options, bounds=theta_bounds)
#     theta = res_theta['x']

# SPSA

initial_c = 0.01
target_update = 2 * np.pi * 0.1
max_trials = 10

gen_params = SPSA_calibration(generator_obj, theta, initial_c, target_update, stat=25)
dis_params = SPSA_calibration(discriminator_obj, phi, initial_c, target_update, stat=25)


for t in range(max_iter):

    logger.log_scalar('theta', theta[0], t)

    def generator_obj(_theta):
        return loss_generator(_theta, phi)

    theta = SPSA_optimization(generator_obj, initial_theta=theta, SPSA_parameters=gen_params, max_trials=max_trials)[1]

    def discriminator_obj(_phi):
        return loss_discriminator(_phi, theta)

    phi = SPSA_optimization(discriminator_obj, initial_theta=phi, SPSA_parameters=dis_params, max_trials=max_trials)[1]
# Out:
# calibration step # 0 of 25
# calibration step # 5 of 25
# calibration step # 10 of 25
# calibration step # 15 of 25
# calibration step # 20 of 25
# calibrated SPSA_parameters[0] is 0.7412421
# calibration step # 0 of 25
# calibration step # 5 of 25
# calibration step # 10 of 25
# calibration step # 15 of 25
# calibration step # 20 of 25
# calibrated SPSA_parameters[0] is 0.5058162
# objective function at theta+ for step # 0
# -0.4111328
# objective function at theta- for step # 0
# -0.4443359
# objective function at theta+ for step # 1
# -0.4130859
# objective function at theta- for step # 1
# -0.3662109
# objective function at theta+ for step # 2
# -0.4062500
# objective function at theta- for step # 2
# -0.4248047
# objective function at theta+ for step # 3
# -0.3759766
# objective function at theta- for step # 3
# -0.4003906
# objective function at theta+ for step # 4
# -0.3857422
# objective function at theta- for step # 4
# -0.3925781
# objective function at theta+ for step # 5
# -0.4121094
# objective function at theta- for step # 5
# -0.4189453
# objective function at theta+ for step # 6
# -0.4179688
# objective function at theta- for step # 6
# -0.4257812
# objective function at theta+ for step # 7
# -0.4423828
# objective function at theta- for step # 7
# -0.3916016
# objective function at theta+ for step # 8
# -0.4091797
# objective function at theta- for step # 8
# -0.4218750
# objective function at theta+ for step # 9
# -0.4121094
# objective function at theta- for step # 9
# -0.4130859
# Final objective function is: -0.4072266
# objective function at theta+ for step # 0
# -0.4169922
# objective function at theta- for step # 0
# -0.4013672
# objective function at theta+ for step # 1
# -0.5585938
# objective function at theta- for step # 1
# -0.5898438
# objective function at theta+ for step # 2
# -0.3642578
# objective function at theta- for step # 2
# -0.2626953
# objective function at theta+ for step # 3
# -0.9746094
# objective function at theta- for step # 3
# -0.9482422
# objective function at theta+ for step # 4
# -0.8408203
# objective function at theta- for step # 4
# -0.8632812
# objective function at theta+ for step # 5
# -0.8818359
# objective function at theta- for step # 5
# -0.9287109
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -0.9960938
# objective function at theta+ for step # 8
# -1.0009766
# objective function at theta- for step # 8
# -1.0009766
# objective function at theta+ for step # 9
# -0.9951172
# objective function at theta- for step # 9
# -1.0009766
# Final objective function is: -0.9980469
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -0.9990234
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -0.9980469
# objective function at theta- for step # 0
# -1.0009766
# objective function at theta+ for step # 1
# -0.9980469
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -0.9990234
# objective function at theta- for step # 2
# -0.9941406
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0019531
# objective function at theta+ for step # 5
# -1.0009766
# objective function at theta- for step # 5
# -0.9990234
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -0.9980469
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0009766
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0009766
# objective function at theta+ for step # 3
# -1.0009766
# objective function at theta- for step # 3
# -0.9980469
# objective function at theta+ for step # 4
# -0.9990234
# objective function at theta- for step # 4
# -1.0019531
# objective function at theta+ for step # 5
# -1.0029297
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -0.9990234
# objective function at theta- for step # 6
# -0.9980469
# objective function at theta+ for step # 7
# -1.0019531
# objective function at theta- for step # 7
# -0.9980469
# objective function at theta+ for step # 8
# -1.0009766
# objective function at theta- for step # 8
# -1.0048828
# objective function at theta+ for step # 9
# -0.9970703
# objective function at theta- for step # 9
# -0.9912109
# Final objective function is: -1.0019531
# objective function at theta+ for step # 0
# -0.9941406
# objective function at theta- for step # 0
# -0.9960938
# objective function at theta+ for step # 1
# -0.9970703
# objective function at theta- for step # 1
# -0.9980469
# objective function at theta+ for step # 2
# -0.9970703
# objective function at theta- for step # 2
# -0.9980469
# objective function at theta+ for step # 3
# -0.9980469
# objective function at theta- for step # 3
# -0.9980469
# objective function at theta+ for step # 4
# -0.9960938
# objective function at theta- for step # 4
# -0.9980469
# objective function at theta+ for step # 5
# -0.9931641
# objective function at theta- for step # 5
# -0.9951172
# objective function at theta+ for step # 6
# -0.9990234
# objective function at theta- for step # 6
# -0.9970703
# objective function at theta+ for step # 7
# -0.9990234
# objective function at theta- for step # 7
# -0.9960938
# objective function at theta+ for step # 8
# -0.9990234
# objective function at theta- for step # 8
# -0.9970703
# objective function at theta+ for step # 9
# -0.9990234
# objective function at theta- for step # 9
# -0.9951172
# Final objective function is: -0.9980469
# objective function at theta+ for step # 0
# -0.9960938
# objective function at theta- for step # 0
# -0.9951172
# objective function at theta+ for step # 1
# -0.9921875
# objective function at theta- for step # 1
# -0.9970703
# objective function at theta+ for step # 2
# -0.9746094
# objective function at theta- for step # 2
# -0.9990234
# objective function at theta+ for step # 3
# -0.9375000
# objective function at theta- for step # 3
# -0.8964844
# objective function at theta+ for step # 4
# -0.9980469
# objective function at theta- for step # 4
# -0.9980469
# objective function at theta+ for step # 5
# -0.9980469
# objective function at theta- for step # 5
# -1.0019531
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -0.9980469
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0009766
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0009766
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -0.9990234
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -0.9990234
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0009766
# objective function at theta+ for step # 6
# -0.9980469
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -0.9960938
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0009766
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -0.9990234
# objective function at theta+ for step # 3
# -0.9990234
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -0.9990234
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0009766
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -0.9970703
# objective function at theta- for step # 3
# -1.0029297
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -0.9970703
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0009766
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -0.9980469
# objective function at theta- for step # 5
# -0.9980469
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -0.9960938
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0009766
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -0.9990234
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -0.9990234
# objective function at theta+ for step # 4
# -0.9990234
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -0.9990234
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -0.9990234
# objective function at theta+ for step # 8
# -0.9990234
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -0.9970703
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0009766
# objective function at theta+ for step # 2
# -1.0019531
# objective function at theta- for step # 2
# -0.9990234
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -0.9990234
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -0.9980469
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0009766
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0019531
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -0.9980469
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -0.9990234
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -0.9990234
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -0.9990234
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -0.9980469
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -0.9990234
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -0.9980469
# objective function at theta+ for step # 4
# -0.9960938
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -0.9980469
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -0.9990234
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0009766
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -0.9980469
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0009766
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# ...
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -0.9980469
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -0.9980469
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0009766
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0009766
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0009766
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0009766
# objective function at theta- for step # 3
# -1.0009766
# objective function at theta+ for step # 4
# -0.9990234
# objective function at theta- for step # 4
# -0.9980469
# objective function at theta+ for step # 5
# -1.0009766
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -0.9960938
# objective function at theta- for step # 6
# -0.9980469
# objective function at theta+ for step # 7
# -0.9980469
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0009766
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -0.9990234
# objective function at theta+ for step # 1
# -0.9990234
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -0.9990234
# objective function at theta+ for step # 3
# -0.9990234
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -0.9980469
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -0.9990234
# objective function at theta+ for step # 2
# -0.9990234
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# objective function at theta+ for step # 0
# -1.0000000
# objective function at theta- for step # 0
# -1.0000000
# objective function at theta+ for step # 1
# -1.0000000
# objective function at theta- for step # 1
# -1.0000000
# objective function at theta+ for step # 2
# -1.0000000
# objective function at theta- for step # 2
# -1.0000000
# objective function at theta+ for step # 3
# -1.0000000
# objective function at theta- for step # 3
# -1.0000000
# objective function at theta+ for step # 4
# -1.0000000
# objective function at theta- for step # 4
# -1.0000000
# objective function at theta+ for step # 5
# -1.0000000
# objective function at theta- for step # 5
# -1.0000000
# objective function at theta+ for step # 6
# -1.0000000
# objective function at theta- for step # 6
# -1.0000000
# objective function at theta+ for step # 7
# -1.0000000
# objective function at theta- for step # 7
# -1.0000000
# objective function at theta+ for step # 8
# -1.0000000
# objective function at theta- for step # 8
# -1.0000000
# objective function at theta+ for step # 9
# -1.0000000
# objective function at theta- for step # 9
# -1.0000000
# Final objective function is: -1.0000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-10a99ed9d0aa> in <module>()
#     145         return loss_discriminator(_phi, theta)
#     146
# --> 147     phi = SPSA_optimization(discriminator_obj, initial_theta=phi, SPSA_parameters=dis_params, max_trials=max_trials)[1]
#     148
#     149
#
# /anaconda/lib/python3.6/site-packages/qiskit/tools/apps/optimization.py in SPSA_optimization(obj_fun, initial_theta, SPSA_parameters, max_trials, save_steps, last_avg)
#      72         # cost fuction for the two directions
#      73         cost_plus = obj_fun(theta_plus)
# ---> 74         cost_minus = obj_fun(theta_minus)
#      75         # derivative estimate
#      76         g_spsa = (cost_plus - cost_minus) * delta / (2.0 * c_spsa)
#
# <ipython-input-5-10a99ed9d0aa> in discriminator_obj(_phi)
#     143
#     144     def discriminator_obj(_phi):
# --> 145         return loss_discriminator(_phi, theta)
#     146
#     147     phi = SPSA_optimization(discriminator_obj, initial_theta=phi, SPSA_parameters=dis_params, max_trials=max_trials)[1]
#
# <ipython-input-5-10a99ed9d0aa> in loss_discriminator(phi, theta)
#      71
#      72 def loss_discriminator(phi, theta):
# ---> 73     d_prob = discriminator_probability(theta, phi, circuit_name='d_circuit', shots=SHOTS)
#      74     d_g_prob = discriminator_probability(theta, phi, circuit_name='d_g_circuit', shots=SHOTS)
#      75     vf = 2*d_prob - d_g_prob
#
# <ipython-input-5-10a99ed9d0aa> in discriminator_probability(theta, phi, circuit_name, shots)
#      58     else:
#      59         build_discriminator_generator(theta, phi)
# ---> 60     stats_generator = Q_program.execute([circuit_name], backend='local_qasm_simulator', shots=shots)
#      61     stats = stats_generator.get_counts(circuit_name)
#      62     return stats['1'] / shots if '1' in stats else 0.0
#
# /anaconda/lib/python3.6/site-packages/qiskit/_quantumprogram.py in execute(self, name_of_circuits, backend, config, timeout, basis_gates, coupling_map, initial_layout, shots, max_credits, seed, hpc, skip_transpiler, skip_translation)
#    1204                             shots=shots, max_credits=max_credits, seed=seed,
#    1205                             hpc=hpc, skip_transpiler=skip_transpiler)
# -> 1206         result = self.run(qobj, timeout=timeout)
#    1207         return result
#    1208
#
# /anaconda/lib/python3.6/site-packages/qiskit/_quantumprogram.py in run(self, qobj, timeout)
#    1094         """
#    1095         job = self._run_internal([qobj])[0]
# -> 1096         return job.result(timeout=timeout)
#    1097
#    1098     def run_batch(self, qobj_list, timeout=120):
#
# /anaconda/lib/python3.6/site-packages/qiskit/backends/local/localjob.py in result(self, timeout)
#      55             concurrent.futures.CancelledError: if job cancelled before completed.
#      56         """
# ---> 57         return self._future.result(timeout=timeout)
#      58
#      59     def cancel(self):
#
# /anaconda/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     398                 return self.__get_result()
#     399
# --> 400             self._condition.wait(timeout)
#     401
#     402             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /anaconda/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np
import qiskit as qs
import tensorflow as tf



from numpy.random import seed
seed(1)
from datetime import datetime
from scipy.optimize import minimize
from logger import Logger
from qiskit.tools.apps.optimization import SPSA_optimization, SPSA_calibration

SHOTS = 1024 

Q_program = qs.QuantumProgram()


def build_discriminator_gates(phi, circuit, q_register, c_register):
    # phase - cnot - phase - cnot - measurement
    circuit.rx(phi[0], q_register[0])
    circuit.rx(phi[1], q_register[1])
    circuit.cx(q_register[0], q_register[1])
    circuit.rz(phi[2], q_register[0])
    circuit.rz(phi[3], q_register[1])
    circuit.cx(q_register[0], q_register[1])
    circuit.measure(q_register[0], c_register[0])


def build_generator_gates(theta, circuit, q_register):
    circuit.x(q_register[0])
    circuit.u1(theta[0], q_register[0])


def build_discriminator_generator(theta, phi):
    d_g_quantum_register = Q_program.create_quantum_register('d_g_qr', 2)
    d_g_classical_register = Q_program.create_classical_register('d_g_cr', 1)
    d_g_circuit = Q_program.create_circuit('d_g_circuit', [d_g_quantum_register], [d_g_classical_register])

    build_generator_gates(theta, d_g_circuit, d_g_quantum_register)
    build_discriminator_gates(phi, d_g_circuit, d_g_quantum_register, d_g_classical_register)


def build_discriminator(phi):
    d_quantum_register = Q_program.create_quantum_register('d_qr', 2)
    d_classical_register = Q_program.create_classical_register('d_cr', 1)
    d_circuit = Q_program.create_circuit('d_circuit', [d_quantum_register], [d_classical_register])

    # prepare target state
    d_circuit.x(d_quantum_register[0])
    d_circuit.z(d_quantum_register[0])

    build_discriminator_gates(phi, d_circuit, d_quantum_register, d_classical_register)


def discriminator_probability(theta, phi, circuit_name, shots):
    if circuit_name == 'd_circuit':
        build_discriminator(phi)
    else:
        build_discriminator_generator(theta, phi)
    stats_generator = Q_program.execute([circuit_name], backend='local_qasm_simulator', shots=shots)
    stats = stats_generator.get_counts(circuit_name)
    return stats['1'] / shots if '1' in stats else 0.0

# def value_function(theta, phi):
#     d_prob = discriminator_probability(theta, phi, circuit_name='d_circuit', shots=shots)
#     d_g_prob = discriminator_probability(theta, phi, circuit_name='d_g_circuit', shots=shots)
#     # vf = np.log(d_prob) + np.log(1 - d_g_prob)
#     vf = d_prob - d_g_prob
#     return vf


def loss_discriminator(phi, theta):
    d_prob = discriminator_probability(theta, phi, circuit_name='d_circuit', shots=SHOTS)
    d_g_prob = discriminator_probability(theta, phi, circuit_name='d_g_circuit', shots=SHOTS)
    vf = d_prob - d_g_prob
    return - vf


def loss_generator(theta, phi):
    d_g_prob = discriminator_probability(theta, phi, circuit_name='d_g_circuit', shots=SHOTS)
    return -tf.abs(d_g_prob)


# options = {'maxiter': 5}
options = None

theta_max = 2 * np.pi
phi_max = 2 * np.pi

theta = np.array([np.random.uniform(0, theta_max)])
theta_bounds = [(0.0, theta_max)]

phi = np.array([np.random.uniform(0.0, phi_max) for _ in range(4)])
phi_bounds = [(0.0, phi_max) for _ in range(4)]

# method = 'L-BFGS-B'
# method = 'TNC'
method ='SLSQP'

max_iter = 10000


# make a plot of the loss landscape

# x = [i * 2 * np.pi / 100 for i in range(100)]
# y = [loss_generator([theta], phi) for theta in x]
# plt.scatter(x, y)
# plt.savefig('generator_loss.pdf')

now = datetime.now().replace(microsecond=0).isoformat()


logger = Logger('logs/{}'.format(now))

# scipy

# for t in range(max_iter):
#     logger.log_scalar('theta', theta[0], t)
#
#     res_phi = minimize(loss_discriminator, args=(theta), x0=phi, method=method, options=options, bounds=phi_bounds)
#     phi = res_phi['x']
#     res_theta = minimize(loss_generator, args=(phi), x0=theta, method=method, options=options, bounds=theta_bounds)
#     theta = res_theta['x']

# # SPSA

# initial_c = 0.01
# target_update = 2 * np.pi * 0.1
# max_trials = 10

# gen_params = SPSA_calibration(generator_obj, theta, initial_c, target_update, stat=25)
# dis_params = SPSA_calibration(discriminator_obj, phi, initial_c, target_update, stat=25)


# for t in range(max_iter):

#     logger.log_scalar('theta', theta[0], t)

#     def generator_obj(_theta):
#         return loss_generator(_theta, phi)

#     theta = SPSA_optimization(generator_obj, initial_theta=theta, SPSA_parameters=gen_params, max_trials=max_trials)[1]

#     def discriminator_obj(_phi):
#         return loss_discriminator(_phi, theta)

#     phi = SPSA_optimization(discriminator_obj, initial_theta=phi, SPSA_parameters=dis_params, max_trials=max_trials)[1]


# Using Adam algorithm for optimization
optimiser = tf.train.AdamOptimizer()
min_cost = optimiser.minimize(loss_generator(theta, phi))

# Begin Tensorflow session
session = tf.Session()
session.run(tf.global_variables_initializer())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-12f12887c013> in <module>()
#     152 # Using Adam algorithm for optimization
#     153 optimiser = tf.train.AdamOptimizer()
# --> 154 min_cost = optimiser.minimize(loss_generator(theta, phi))
#     155
#     156 # Begin Tensorflow session
#
# /anaconda/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py in minimize(self, loss, global_step, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, name, grad_loss)
#     398         aggregation_method=aggregation_method,
#     399         colocate_gradients_with_ops=colocate_gradients_with_ops,
# --> 400         grad_loss=grad_loss)
#     401
#     402     vars_with_grad = [v for g, v in grads_and_vars if g is not None]
#
# /anaconda/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py in compute_gradients(self, loss, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, grad_loss)
#     506     processors = [_get_processor(v) for v in var_list]
#     507     if not var_list:
# --> 508       raise ValueError("No variables to optimize.")
#     509     var_refs = [p.target() for p in processors]
#     510     grads = gradients.gradients(
#
# ValueError: No variables to optimize.
